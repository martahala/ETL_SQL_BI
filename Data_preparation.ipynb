# %%
import pandas as pd 
import numpy as np
from datetime import datetime, timedelta
import random

random.seed(123)

# Data load
df = pd.read_csv('/superstore.csv', encoding='latin1')
print(df.head()) # Data check
print(df.columns) # Columns check
      
# Ensure required columns exist 
required_cols = ['Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
       'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
       'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
       'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit']
for c in required_cols: 
    if c not in df.columns: 
        raise SystemExit(f"Missing column: {c}")

# Rename columns to safe names 
df = df[required_cols].rename(columns={ 'Order ID':'order_id','Order Date':'order_date','Ship Date':'ship_date',
                                       'Ship Mode':'ship_mode', 'Customer ID':'customer_id','Customer Name':'customer_name',
                                       'Segment':'segment','Country':'country', 'City':'city','State':'state','Postal Code':'postal_code', 
                                       'Region':'region','Product ID':'product_id','Category':'category', 'Sub-Category':'sub_category',
                                       'Product Name':'product_name','Sales':'sales','Quantity':'quantity', 'Discount':'discount','Profit':'profit' })
print(df.head()) # Column renaming check

# Convert dates 
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce') 
df['ship_date'] = pd.to_datetime(df['ship_date'], errors='coerce')

# Create initial load (a random snapshot)
initial = df.copy().reset_index(drop=True)
# Save initial load 
initial.to_csv('/initial_load.csv', index=False)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    postal_code region       product_id         category sub_category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
# 4        33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_id, customer_name, segment, country, city, state, postal_code, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit]
# Index: []

# %%
# --- Create secondary load with: 
# - some new records 
# - some SCD1 changes (customer name corrected) 
# - some SCD2 changes (customer region changed) 
# - some exact duplicates of initial rows 
# - some modified orders (e.g., changed profit value) for SCD1-like behavior


secondary = pd.DataFrame(columns=initial.columns)
print(secondary)

n = len(initial)
print(n)
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_id, customer_name, segment, country, city, state, postal_code, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit]
# Index: []
# 9994

# %%
# Keep 70% of rows unchanged (simulate unchanged shipments) 
unchanged_idx = initial.sample(frac=0.70, random_state=1).index 
secondary = pd.concat([secondary, initial.loc[unchanged_idx]], ignore_index=True)

print(secondary)
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 0     CA-2015-131597 2015-09-14 2015-09-18  Standard Class    SP-20620
# 1     CA-2015-129098 2015-10-09 2015-10-13  Standard Class    DK-13090
# 2     US-2014-147627 2014-01-20 2014-01-26  Standard Class    HL-15040
# 3     CA-2015-128125 2015-03-31 2015-04-05  Standard Class    EB-13705
# 4     CA-2014-113929 2014-06-16 2014-06-21  Standard Class    CK-12205
# ...              ...        ...        ...             ...         ...
# 6991  CA-2014-149958 2014-03-15 2014-03-19  Standard Class    AS-10240
# 6992  CA-2014-127012 2014-08-11 2014-08-15  Standard Class    GM-14680
# 6993  CA-2017-169404 2017-04-09 2017-04-14  Standard Class    NC-18625
# 6994  CA-2017-142636 2017-11-03 2017-11-07  Standard Class    KC-16675
# 6995  CA-2015-115742 2015-04-18 2015-04-22  Standard Class    DP-13000
#
#             customer_name    segment        country         city  \
# 0        Stefania Perrino  Corporate  United States  Los Angeles
# 1               Dave Kipp   Consumer  United States  Springfield
# 2            Hunter Lopez   Consumer  United States    Jonesboro
# 3              Ed Braxton  Corporate  United States      Houston
# 4     Chloris Kastensmidt   Consumer  United States    Hempstead
# ...                   ...        ...            ...          ...
# 6991         Alan Shonely   Consumer  United States        Tampa
# 6992        Greg Matthias   Consumer  United States      Seattle
# 6993          Noah Childs  Corporate  United States         York
# 6994      Kimberly Carter  Corporate  United States      Seattle
# 6995        Darren Powers   Consumer  United States   New Albany
#
#              state postal_code   region       product_id         category  \
# 0       California       90045     West  FUR-TA-10002607        Furniture
# 1         Virginia       22153    South  OFF-ST-10001321  Office Supplies
# 2         Arkansas       72401    South  OFF-AR-10002375  Office Supplies
# 3            Texas       77095  Central  OFF-PA-10000357  Office Supplies
# 4         New York       11550     East  OFF-EN-10003286  Office Supplies
# ...            ...         ...      ...              ...              ...
# 6991       Florida       33614    South  OFF-BI-10000773  Office Supplies
# 6992    Washington       98105     West  OFF-AR-10003903  Office Supplies
# 6993  Pennsylvania       17403     East  OFF-PA-10001033  Office Supplies
# 6994    Washington       98105     West  FUR-CH-10001891        Furniture
# 6995       Indiana       47150  Central  OFF-BI-10004410  Office Supplies
#
#      sub_category                                       product_name    sales  \
# 0          Tables                               KI Conference Tables  170.136
# 1         Storage        Decoflex Hanging Personal Folder File, Blue   30.840
# 2             Art                                         Newell 351   22.960
# 3           Paper  White Dual Perf Computer Printout Paper, 2700 ...   98.376
# 4       Envelopes                                    Staple envelope   41.400
# ...           ...                                                ...      ...
# 6991      Binders                Insertable Tab Post Binder Dividers    7.218
# 6992          Art      Sanford 52201 APSCO Electric Pencil Sharpener   40.970
# 6993        Paper                                         Xerox 1893   65.584
# 6994       Chairs                 Global Deluxe Office Fabric Chairs  307.136
# 6995      Binders  C-Line Peel & Stick Add-On Filing Pockets, 8-3...   38.220
#
#      quantity  discount   profit
# 0           3       0.2  -8.5068
# 1           2       0.0   8.3268
# 2           7       0.0   6.6584
# 3           3       0.2  35.6613
# 4           5       0.0  19.4580
# ...       ...       ...      ...
# 6991        3       0.7  -5.5338
# 6992        1       0.0  10.6522
# 6993        2       0.2  23.7742
# 6994        4       0.2  26.8744
# 6995        6       0.0  17.9634
#
# [6996 rows x 20 columns]
# /var/folders/1x/kg3kyc1n25vcq0b26636jq040000gn/T/ipykernel_2331/2772392141.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   secondary = pd.concat([secondary, initial.loc[unchanged_idx]], ignore_index=True)

# %%
# New records: 3% new orders with new order_id and new customer_id 
new_count = int(n * 0.03) # 3% of the dataset will be new rows
sample_for_template = initial.sample(n=new_count, random_state=5) # Pick some rows from the initial dataset as templates
new_rows = sample_for_template.copy() 
for i in range(len(new_rows)): # Create new order id and new customer id 
    new_rows.iloc[i, new_rows.columns.get_loc('order_id')] = f"NEWORD{100000 + i}" # Assign a new unique order ID like 'NEWWORD01'
    new_rows.iloc[i, new_rows.columns.get_loc('customer_id')] = f"NEWCUST{10000 + i}" # Assign a new unique customer ID like 'NEWCUST01'
    new_rows.iloc[i, new_rows.columns.get_loc('customer_name')] = f"New Customer {i}" # Assign a name like 'New Customer 0' etc.
    # shift date forward 
    new_rows.iloc[i, new_rows.columns.get_loc('order_date')] = new_rows.iloc[i]['order_date'] + pd.Timedelta(days=30) # Add 30 days to the original order_date to look like new orders
secondary=pd.concat([secondary,new_rows], ignore_index=True)
print(secondary)
# Out:
#             order_id order_date  ship_date       ship_mode   customer_id  \
# 0     CA-2015-131597 2015-09-14 2015-09-18  Standard Class      SP-20620
# 1     CA-2015-129098 2015-10-09 2015-10-13  Standard Class      DK-13090
# 2     US-2014-147627 2014-01-20 2014-01-26  Standard Class      HL-15040
# 3     CA-2015-128125 2015-03-31 2015-04-05  Standard Class      EB-13705
# 4     CA-2014-113929 2014-06-16 2014-06-21  Standard Class      CK-12205
# ...              ...        ...        ...             ...           ...
# 7290    NEWORD100294 2017-04-26 2017-03-29    Second Class  NEWCUST10294
# 7291    NEWORD100295 2017-12-09 2017-11-12    Second Class  NEWCUST10295
# 7292    NEWORD100296 2014-06-03 2014-05-05     First Class  NEWCUST10296
# 7293    NEWORD100297 2017-01-02 2016-12-07  Standard Class  NEWCUST10297
# 7294    NEWORD100298 2016-10-17 2016-09-22  Standard Class  NEWCUST10298
#
#             customer_name    segment        country         city       state  \
# 0        Stefania Perrino  Corporate  United States  Los Angeles  California
# 1               Dave Kipp   Consumer  United States  Springfield    Virginia
# 2            Hunter Lopez   Consumer  United States    Jonesboro    Arkansas
# 3              Ed Braxton  Corporate  United States      Houston       Texas
# 4     Chloris Kastensmidt   Consumer  United States    Hempstead    New York
# ...                   ...        ...            ...          ...         ...
# 7290     New Customer 294   Consumer  United States     Richmond    Virginia
# 7291     New Customer 295  Corporate  United States     Columbia    Maryland
# 7292     New Customer 296   Consumer  United States      Houston       Texas
# 7293     New Customer 297   Consumer  United States     Richmond     Indiana
# 7294     New Customer 298  Corporate  United States       Bangor       Maine
#
#      postal_code   region       product_id         category sub_category  \
# 0          90045     West  FUR-TA-10002607        Furniture       Tables
# 1          22153    South  OFF-ST-10001321  Office Supplies      Storage
# 2          72401    South  OFF-AR-10002375  Office Supplies          Art
# 3          77095  Central  OFF-PA-10000357  Office Supplies        Paper
# 4          11550     East  OFF-EN-10003286  Office Supplies    Envelopes
# ...          ...      ...              ...              ...          ...
# 7290       23223    South  OFF-BI-10001679  Office Supplies      Binders
# 7291       21044     East  OFF-BI-10004728  Office Supplies      Binders
# 7292       77036  Central  OFF-FA-10000840  Office Supplies    Fasteners
# 7293       47374  Central  FUR-CH-10004754        Furniture       Chairs
# 7294        4401     East  TEC-PH-10001944       Technology       Phones
#
#                                            product_name    sales quantity  \
# 0                                  KI Conference Tables  170.136        3
# 1           Decoflex Hanging Personal Folder File, Blue   30.840        2
# 2                                            Newell 351   22.960        7
# 3     White Dual Perf Computer Printout Paper, 2700 ...   98.376        3
# 4                                       Staple envelope   41.400        5
# ...                                                 ...      ...      ...
# 7290       GBC Instant Index System for Binding Systems   17.760        2
# 7291  Wilson Jones Turn Tabs Binder Tool for Ring Bi...    9.640        2
# 7292                                    OIC Thumb-Tacks    5.472        6
# 7293                Global Stack Chair with Arms, Black   29.980        1
# 7294   Wi-Ex zBoost YX540 Cellular Phone Signal Booster  437.850        3
#
#       discount    profit
# 0          0.2   -8.5068
# 1          0.0    8.3268
# 2          0.0    6.6584
# 3          0.2   35.6613
# 4          0.0   19.4580
# ...        ...       ...
# 7290       0.0    8.8800
# 7291       0.0    4.4344
# 7292       0.2    1.8468
# 7293       0.0    8.0946
# 7294       0.0  131.3550
#
# [7295 rows x 20 columns]

# %%
# Create SCD1 changes: customer_name corrections for some customer_ids (3%) 
s1_idx = initial.sample(frac=0.03, random_state=3).index # Select some rows to modify
s1_rows = initial.loc[s1_idx].copy() 
# Flip a character in customer_name to simulate correction  
s1_rows['customer_name'] = s1_rows['customer_name'].apply(lambda x: f"Corrected {x}") 
secondary = pd.concat([secondary,s1_rows], ignore_index=True)
print(secondary)
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 0     CA-2015-131597 2015-09-14 2015-09-18  Standard Class    SP-20620
# 1     CA-2015-129098 2015-10-09 2015-10-13  Standard Class    DK-13090
# 2     US-2014-147627 2014-01-20 2014-01-26  Standard Class    HL-15040
# 3     CA-2015-128125 2015-03-31 2015-04-05  Standard Class    EB-13705
# 4     CA-2014-113929 2014-06-16 2014-06-21  Standard Class    CK-12205
# ...              ...        ...        ...             ...         ...
# 7590  CA-2016-133669 2016-10-21 2016-10-27  Standard Class    SV-20935
# 7591  CA-2016-125017 2016-02-06 2016-02-11  Standard Class    KB-16240
# 7592  CA-2016-125843 2016-08-13 2016-08-16     First Class    RF-19840
# 7593  CA-2014-146283 2014-09-08 2014-09-15  Standard Class    KT-16465
# 7594  CA-2014-145317 2014-03-18 2014-03-23  Standard Class    SM-20320
#
#                   customer_name      segment        country          city  \
# 0              Stefania Perrino    Corporate  United States   Los Angeles
# 1                     Dave Kipp     Consumer  United States   Springfield
# 2                  Hunter Lopez     Consumer  United States     Jonesboro
# 3                    Ed Braxton    Corporate  United States       Houston
# 4           Chloris Kastensmidt     Consumer  United States     Hempstead
# ...                         ...          ...            ...           ...
# 7590  Corrected Susan Vittorini     Consumer  United States      Columbus
# 7591       Corrected Karen Bern    Corporate  United States   Chattanooga
# 7592  Corrected Roy Französisch     Consumer  United States   Springfield
# 7593    Corrected Kean Takahito     Consumer  United States       Houston
# 7594      Corrected Sean Miller  Home Office  United States  Jacksonville
#
#            state postal_code   region       product_id         category  \
# 0     California       90045     West  FUR-TA-10002607        Furniture
# 1       Virginia       22153    South  OFF-ST-10001321  Office Supplies
# 2       Arkansas       72401    South  OFF-AR-10002375  Office Supplies
# 3          Texas       77095  Central  OFF-PA-10000357  Office Supplies
# 4       New York       11550     East  OFF-EN-10003286  Office Supplies
# ...          ...         ...      ...              ...              ...
# 7590        Ohio       43229     East  TEC-PH-10001305       Technology
# 7591   Tennessee       37421    South  FUR-FU-10000723        Furniture
# 7592    Virginia       22153    South  OFF-LA-10003923  Office Supplies
# 7593       Texas       77036  Central  OFF-PA-10000482  Office Supplies
# 7594     Florida       32216    South  OFF-PA-10001804  Office Supplies
#
#      sub_category                                       product_name    sales  \
# 0          Tables                               KI Conference Tables  170.136
# 1         Storage        Decoflex Hanging Personal Folder File, Blue   30.840
# 2             Art                                         Newell 351   22.960
# 3           Paper  White Dual Perf Computer Printout Paper, 2700 ...   98.376
# 4       Envelopes                                    Staple envelope   41.400
# ...           ...                                                ...      ...
# 7590       Phones                   Panasonic KX TS208W Corded phone  235.152
# 7591  Furnishings  Deflect-o EconoMat Studded, No Bevel Mat for L...  132.224
# 7592       Labels             Alphabetical Labels for Top Tab Filing  103.600
# 7593        Paper  Snap-A-Way Black Print Carbonless Ruled Speed ...  182.112
# 7594        Paper                                          Xerox 195   21.376
#
#      quantity  discount   profit
# 0           3       0.2  -8.5068
# 1           2       0.0   8.3268
# 2           7       0.0   6.6584
# 3           3       0.2  35.6613
# 4           5       0.0  19.4580
# ...       ...       ...      ...
# 7590        8       0.4 -47.0304
# 7591        4       0.2 -18.1808
# 7592        7       0.0  51.8000
# 7593        6       0.2  61.4628
# 7594        4       0.2   7.4816
#
# [7595 rows x 20 columns]

# %%
# Create SCD2 changes: same customer_id but different region for some rows (2%) 
s2_idx = initial.sample(frac=0.02, random_state=3).index 
s2_rows = initial.loc[s2_idx].copy() 
# Change region to a different valid value (choose one not equal to original) 
all_regions = initial['region'].unique().tolist() 
def different_region(r): 
    choices = [x for x in all_regions if x != r] 
    return random.choice(choices) if choices else r 
s2_rows['region'] = s2_rows['region'].apply(different_region) 
# Update order_date to a later date in order to simulate later event 
s2_rows['order_date'] = s2_rows['order_date'] + pd.Timedelta(days=180) 
secondary = pd.concat([secondary,s2_rows], ignore_index=True)
print(secondary)
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 0     CA-2015-131597 2015-09-14 2015-09-18  Standard Class    SP-20620
# 1     CA-2015-129098 2015-10-09 2015-10-13  Standard Class    DK-13090
# 2     US-2014-147627 2014-01-20 2014-01-26  Standard Class    HL-15040
# 3     CA-2015-128125 2015-03-31 2015-04-05  Standard Class    EB-13705
# 4     CA-2014-113929 2014-06-16 2014-06-21  Standard Class    CK-12205
# ...              ...        ...        ...             ...         ...
# 7790  CA-2016-109666 2016-10-16 2016-04-26  Standard Class    KM-16720
# 7791  CA-2015-126557 2016-01-08 2015-07-17    Second Class    RL-19615
# 7792  CA-2014-159835 2015-05-16 2014-11-24  Standard Class    RB-19330
# 7793  CA-2014-131947 2015-03-16 2014-09-22  Standard Class    JA-15970
# 7794  CA-2015-149909 2016-05-11 2015-11-17  Standard Class    RA-19915
#
#             customer_name    segment        country           city  \
# 0        Stefania Perrino  Corporate  United States    Los Angeles
# 1               Dave Kipp   Consumer  United States    Springfield
# 2            Hunter Lopez   Consumer  United States      Jonesboro
# 3              Ed Braxton  Corporate  United States        Houston
# 4     Chloris Kastensmidt   Consumer  United States      Hempstead
# ...                   ...        ...            ...            ...
# 7790         Kunst Miller   Consumer  United States  New York City
# 7791            Rob Lucas   Consumer  United States        Chicago
# 7792        Randy Bradley   Consumer  United States   Philadelphia
# 7793         Joseph Airdo   Consumer  United States    Springfield
# 7794    Russell Applegate   Consumer  United States       Columbus
#
#              state postal_code   region       product_id         category  \
# 0       California       90045     West  FUR-TA-10002607        Furniture
# 1         Virginia       22153    South  OFF-ST-10001321  Office Supplies
# 2         Arkansas       72401    South  OFF-AR-10002375  Office Supplies
# 3            Texas       77095  Central  OFF-PA-10000357  Office Supplies
# 4         New York       11550     East  OFF-EN-10003286  Office Supplies
# ...            ...         ...      ...              ...              ...
# 7790      New York       10035    South  OFF-ST-10000991  Office Supplies
# 7791      Illinois       60610     West  OFF-AR-10003190  Office Supplies
# 7792  Pennsylvania       19143  Central  FUR-CH-10004997        Furniture
# 7793        Oregon       97477    South  OFF-AR-10001473  Office Supplies
# 7794       Indiana       47201     West  OFF-PA-10001790  Office Supplies
#
#      sub_category                                       product_name    sales  \
# 0          Tables                               KI Conference Tables  170.136
# 1         Storage        Decoflex Hanging Personal Folder File, Blue   30.840
# 2             Art                                         Newell 351   22.960
# 3           Paper  White Dual Perf Computer Printout Paper, 2700 ...   98.376
# 4       Envelopes                                    Staple envelope   41.400
# ...           ...                                                ...      ...
# 7790      Storage      Space Solutions HD Industrial Steel Shelving.  459.880
# 7791          Art                                          Newell 32    6.912
# 7792       Chairs             Hon Every-Day Series Multi-Task Chairs  657.930
# 7793          Art                                         Newell 313    5.248
# 7794        Paper                                         Xerox 1910   96.080
#
#      quantity  discount   profit
# 0           3       0.2  -8.5068
# 1           2       0.0   8.3268
# 2           7       0.0   6.6584
# 3           3       0.2  35.6613
# 4           5       0.0  19.4580
# ...       ...       ...      ...
# 7790        4       0.0  13.7964
# 7791        3       0.2   0.6912
# 7792        5       0.3 -93.9900
# 7793        2       0.2   0.4592
# 7794        2       0.0  46.1184
#
# [7795 rows x 20 columns]

# %%
# Create exact duplicates (5% of initial)
dup_idx = initial.sample(frac=0.05, random_state=2).index
secondary = pd.concat([secondary, initial.loc[dup_idx]], ignore_index=True)
print(secondary)
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 0     CA-2015-131597 2015-09-14 2015-09-18  Standard Class    SP-20620
# 1     CA-2015-129098 2015-10-09 2015-10-13  Standard Class    DK-13090
# 2     US-2014-147627 2014-01-20 2014-01-26  Standard Class    HL-15040
# 3     CA-2015-128125 2015-03-31 2015-04-05  Standard Class    EB-13705
# 4     CA-2014-113929 2014-06-16 2014-06-21  Standard Class    CK-12205
# ...              ...        ...        ...             ...         ...
# 8790  CA-2017-144862 2017-12-01 2017-12-05  Standard Class    EH-14005
# 8791  CA-2015-137064 2015-02-06 2015-02-13  Standard Class    TS-21655
# 8792  CA-2017-114370 2017-03-14 2017-03-17    Second Class    BN-11470
# 8793  CA-2014-127166 2014-05-21 2014-05-23    Second Class    KH-16360
# 8794  CA-2016-103730 2016-06-12 2016-06-15     First Class    SC-20725
#
#             customer_name      segment        country          city  \
# 0        Stefania Perrino    Corporate  United States   Los Angeles
# 1               Dave Kipp     Consumer  United States   Springfield
# 2            Hunter Lopez     Consumer  United States     Jonesboro
# 3              Ed Braxton    Corporate  United States       Houston
# 4     Chloris Kastensmidt     Consumer  United States     Hempstead
# ...                   ...          ...            ...           ...
# 8790      Erica Hernandez  Home Office  United States  Philadelphia
# 8791        Trudy Schmidt     Consumer  United States       Houston
# 8792         Brad Norvell    Corporate  United States       Chicago
# 8793     Katherine Hughes     Consumer  United States       Houston
# 8794    Steven Cartwright     Consumer  United States    Wilmington
#
#              state postal_code   region       product_id         category  \
# 0       California       90045     West  FUR-TA-10002607        Furniture
# 1         Virginia       22153    South  OFF-ST-10001321  Office Supplies
# 2         Arkansas       72401    South  OFF-AR-10002375  Office Supplies
# 3            Texas       77095  Central  OFF-PA-10000357  Office Supplies
# 4         New York       11550     East  OFF-EN-10003286  Office Supplies
# ...            ...         ...      ...              ...              ...
# 8790  Pennsylvania       19143     East  TEC-PH-10000923       Technology
# 8791         Texas       77070  Central  OFF-BI-10002049  Office Supplies
# 8792      Illinois       60623  Central  TEC-PH-10000213       Technology
# 8793         Texas       77070  Central  OFF-EN-10003134  Office Supplies
# 8794      Delaware       19805     East  OFF-BI-10003910  Office Supplies
#
#      sub_category                                       product_name    sales  \
# 0          Tables                               KI Conference Tables  170.136
# 1         Storage        Decoflex Hanging Personal Folder File, Blue   30.840
# 2             Art                                         Newell 351   22.960
# 3           Paper  White Dual Perf Computer Printout Paper, 2700 ...   98.376
# 4       Envelopes                                    Staple envelope   41.400
# ...           ...                                                ...      ...
# 8790       Phones  Belkin SportFit Armband For iPhone 5s/5c, Fuchsia   62.958
# 8791      Binders                          UniKeep View Case Binders    2.934
# 8792       Phones  Seidio BD2-HK3IPH5-BK DILEX Case and Holster C...   49.616
# 8793    Envelopes                                    Staple envelope   56.064
# 8794      Binders  DXL Angle-View Binders with Locking Rings by S...   30.840
#
#      quantity  discount   profit
# 0           3       0.2  -8.5068
# 1           2       0.0   8.3268
# 2           7       0.0   6.6584
# 3           3       0.2  35.6613
# 4           5       0.0  19.4580
# ...       ...       ...      ...
# 8790        7       0.4   9.4437
# 8791        3       0.8  -4.9878
# 8792        2       0.2   4.9616
# 8793        6       0.2  21.0240
# 8794        4       0.0  13.8780
#
# [8795 rows x 20 columns]

# %%
# Shuffle the secondary and save as a csv file
secondary = secondary.sample(frac=1, random_state=7).reset_index(drop=True) 
secondary.to_csv('/secondary_load.csv', index=False)

# %%
print("Created initial_load.csv (rows: {})".format(len(initial))) 
print("Created secondary_load.csv (rows: {})".format(len(secondary)))
# Out:
# Created initial_load.csv (rows: 9994)
# Created secondary_load.csv (rows: 8795)
